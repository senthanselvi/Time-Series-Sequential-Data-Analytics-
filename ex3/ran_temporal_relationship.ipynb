# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
date_range = pd.date_range(start = '1/1/2024',end = '1/31/2024',freq = 'D')
date_range
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10', '2024-01-11', '2024-01-12',
#                '2024-01-13', '2024-01-14', '2024-01-15', '2024-01-16',
#                '2024-01-17', '2024-01-18', '2024-01-19', '2024-01-20',
#                '2024-01-21', '2024-01-22', '2024-01-23', '2024-01-24',
#                '2024-01-25', '2024-01-26', '2024-01-27', '2024-01-28',
#                '2024-01-29', '2024-01-30', '2024-01-31'],
#               dtype='datetime64[ns]', freq='D')

# %%
temp_data = np.random.normal(loc = 10,scale = 5,size = len(date_range))
temp_data
# Out:
# array([14.99974208, 12.58325783, 15.6892207 , 14.72895371, 10.13131699,
#         7.51978354, 15.29488653, 13.16214441, 10.64561574, 13.85532292,
#         9.9079572 ,  3.38480833,  5.52610831, 18.07538199, -0.55934677,
#        15.04100634, 10.60398331,  4.30716265, 12.69853902,  9.79184965,
#         6.17983207,  5.35666307,  0.13472471, 10.01152488, 16.64069483,
#        16.64758502, 15.096458  ,  9.41962056,  8.44844882,  9.16463789,
#         2.44511576])

# %%
temp_df = pd.DataFrame({'Date':date_range,'Temperature':temp_data})
temp_df
# Out:
#          Date  Temperature
# 0  2024-01-01    14.999742
# 1  2024-01-02    12.583258
# 2  2024-01-03    15.689221
# 3  2024-01-04    14.728954
# 4  2024-01-05    10.131317
# 5  2024-01-06     7.519784
# 6  2024-01-07    15.294887
# 7  2024-01-08    13.162144
# 8  2024-01-09    10.645616
# 9  2024-01-10    13.855323
# 10 2024-01-11     9.907957
# 11 2024-01-12     3.384808
# 12 2024-01-13     5.526108
# 13 2024-01-14    18.075382
# 14 2024-01-15    -0.559347
# 15 2024-01-16    15.041006
# 16 2024-01-17    10.603983
# 17 2024-01-18     4.307163
# 18 2024-01-19    12.698539
# 19 2024-01-20     9.791850
# 20 2024-01-21     6.179832
# 21 2024-01-22     5.356663
# 22 2024-01-23     0.134725
# 23 2024-01-24    10.011525
# 24 2024-01-25    16.640695
# 25 2024-01-26    16.647585
# 26 2024-01-27    15.096458
# 27 2024-01-28     9.419621
# 28 2024-01-29     8.448449
# 29 2024-01-30     9.164638
# 30 2024-01-31     2.445116

# %%
temp_df.set_index('Date',inplace = True)

# %%
temp_df.head()
# Out:
#             Temperature
# Date
# 2024-01-01    14.999742
# 2024-01-02    12.583258
# 2024-01-03    15.689221
# 2024-01-04    14.728954
# 2024-01-05    10.131317

# %%
plt.figure(figsize=(8,3))
plt.plot(temp_df.index,temp_df['Temperature'])
plt.title('Daily Temp in Jan24')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(8,3 ))
plt.scatter(temp_df.index,temp_df['Temperature'])
plt.title('Daily Temp in Jan24')
plt.xlabel('Date')
plt.ylabel('Temp in Celsius')
plt.xticks(rotation=30)
plt.show()

# %%
plt.figure(figsize=(8,3 ))
pd.plotting.autocorrelation_plot(temp_df['Temperature'])
plt.title('Autocorrelation plot')
plt.show()

# %%
plt.figure(figsize=(8,3 ))
plt.hist(temp_df['Temperature'],bins=10)
plt.title('Histogram for Daily Temp in Jan24')
plt.ylabel('Frequency')
plt.xlabel('Temp in Celsius')
plt.show()

# %%
plt.figure(figsize=(8,3 ))
sns.kdeplot(temp_df['Temperature'],fill=True)
plt.title('Density plot for Daily Temp in Jan24')
plt.xlabel('Temperature')
plt.show()
# Out:
# C:\Users\admin\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(2,2))
sns.boxplot(x=temp_df['Temperature'])
plt.title('Box and Whisker plot for Daily Tempin Jan24')
plt.xlabel('Temperature')
plt.show()

# %%
plt.figure(figsize=(2,2))
sns.heatmap(temp_df,cmap='coolwarm')
plt.title('Heatmap for Daily Temp in Jan24')
plt.xlabel('Temperature')
plt.show()
